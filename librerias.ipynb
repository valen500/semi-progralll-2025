# %% [markdown]
# <a href="https://colab.research.google.com/github/valen500/semi-progralll-2025/blob/librerias/librerias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "authorship_tag": "ABX9TyOXbuFrehdLgxL4ygNj5uXX",
      "include_colab_link": true
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github",
        "colab_type": "text"
      },
      "source": [
        "<a href=\"https://colab.research.google.com/github/luishernandezpw/PrograIII-Semi-2025/blob/librerias/uso_librerias.ipynb\" target=\"_parent\"><img src=\"https://colab.research.google.com/assets/colab-badge.svg\" alt=\"Open In Colab\"/></a>"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 10,
      "metadata": {
        "id": "bt9tkUzV7wl-"
      },
      "outputs": [],
      "source": [
        "import pandas as pd"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "ruta = \"notas.csv\"\n",
        "notas = pd.read_csv(ruta, sep=\";\", encoding=\"utf-8\")"
      ],
      "metadata": {
        "collapsed": true,
        "id": "Q057bxJIAFMV"
      },
      "execution_count": 12,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "print(notas)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "SB73CPoHAKF4",
        "outputId": "2b18dd01-d25d-42f8-f40d-c5675ac5aeb0"
      },
      "execution_count": 13,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "  alumno  nota\n",
            "0   Luis     5\n",
            "1   Juan     8\n",
            "2  Maria     9\n",
            "3   Jose    10\n"
          ]
        }
      ]
    }
  ]
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3644152629.py in <cell line: 0>()
#       6       "provenance": [],
#       7       "authorship_tag": "ABX9TyOXbuFrehdLgxL4ygNj5uXX",
# ----> 8       "include_colab_link": true
#       9     },
#      10     "kernelspec": {
#
# NameError: name 'true' is not defined

# %%
import pandas as pd

# %%
ruta = "/content/notas.csv"
notas = pd.read_csv(ruta, sep=";", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3378235339.py in <cell line: 0>()
#       1 ruta = "/content/notas.csv"
# ----> 2 notas = pd.read_csv(ruta, sep=";", encoding="utf-8")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/notas.csv'

# %%
print(notas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3287149383.py in <cell line: 0>()
# ----> 1 print(notas)
#
# NameError: name 'notas' is not defined

# %%
print( notas["alumno"][0] )

# %%
#saca el listado de los alumnos aprobados
aprobados  = notas[ notas["nota"]>=6 ]
print(aprobados)

# %%
#sacar el listado de los alumnos reprobados
reprobados = notas[ notas["nota"]<6 ]
print(reprobados)

# %%
print("Cantidad de Alumnos aprobados", len(aprobados))

cantidad_aprobados = notas.loc[ notas["nota"]>=6 ].agg({"count"})
print(cantidad_aprobados)

# %%
print("Cantidad de Alumnos reprobados", len(reprobados))

cantidad_reprobados = notas.loc[ notas["nota"]<6 ].agg({"count"})
print(cantidad_reprobados)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3635929398.py in <cell line: 0>()
# ----> 1 print("Cantidad de Alumnos reprobados", len(reprobados))
#       2
#       3 cantidad_reprobados = notas.loc[ notas["nota"]<6 ].agg({"count"})
#       4 print(cantidad_reprobados)
#
# NameError: name 'reprobados' is not defined

# %%
grupo_notas = notas.groupby(["nota"]).agg({
    'alumno': lambda n: ', '.join( map(str,n) )
})
print(grupo_notas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2232127691.py in <cell line: 0>()
# ----> 1 grupo_notas = notas.groupby(["nota"]).agg({
#       2     'alumno': lambda n: ', '.join( map(str,n) )
#       3 })
#       4 print(grupo_notas)
#
# NameError: name 'notas' is not defined

# %%
#importar las librerias para graficas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
notas['estado'] = notas['nota'].apply(lambda n: 'Aprobado' if n >= 6 else 'Reprobado')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1991228750.py in <cell line: 0>()
# ----> 1 notas['estado'] = notas['nota'].apply(lambda n: 'Aprobado' if n >= 6 else 'Reprobado')
#
# NameError: name 'notas' is not defined

# %%
sns.set(style="whitegrid")
sns.countplot(data=notas, x='estado', palette={'Aprobado': 'green', 'Reprobado': 'red'})
plt.title('Alumnos aprobados y reprobados')
plt.xlabel('Estado')
plt.ylabel('Cantidad de alumnos')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1800193188.py in <cell line: 0>()
#       1 sns.set(style="whitegrid")
# ----> 2 sns.countplot(data=notas, x='estado', palette={'Aprobado': 'green', 'Reprobado': 'red'})
#       3 plt.title('Alumnos aprobados y reprobados')
#       4 plt.xlabel('Estado')
#       5 plt.ylabel('Cantidad de alumnos')
#
# NameError: name 'notas' is not defined

# %%
#importar las librerias necesarias
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
#leer el archivo de las temperaturas para el entrenamiento
grados = pd.read_csv("/content/grados.csv", sep=";", encoding="utf-8")
print(grados, grados["f"])

# %%
c = grados["c"]
f = grados["f"]

print(c,f)

# %%
#modelo
modelo = tf.keras.Sequential()
modelo.add(tf.keras.layers.Dense(units=1, input_shape=[1]))

# %%
#compilar el modelo
modelo.compile(optimizer=tf.keras.optimizers.Adam(1.0), loss='mean_squared_error')

# %%
#entrenar el modelo
epocas = modelo.fit(c, f, epochs=200, verbose=1)

# %%
#prediccion
g = int(input("Celsius: "))
resp = modelo.predict(np.array([g]))
print("Farenheits: ", resp[0][0])

# %%
#guardar el modelo
modelo.save("grados.h5")

# %% [markdown]
# #Entrenar una IA con la libreria de tensorflow que convierta grados celsius a kelvin.
# #el archivo se debe de llamar kelvin.csv

# %% [markdown]
# Uso de APIS de OpenaAI y Google

# %%
##Conexion a ChatGPT de OpenAI
from openai import OpenAI
client = OpenAI(api_key="")
respuesta = client.chat.completions.create(
    model="gpt-5-nano-2025-08-07",
    messages=[{"role":"user","content":""}]
)
print(respuesta.choices[0].message.content)

# %%
#Conexion a Gemini Google
import google.generativeai as genai
genai.configure(api_key="")
#modelo = genai.GenerativeModel("gemini-2.5-pro")
modelo = genai.GenerativeModel("gemini-2.5-flash")

# %%
prompt = input("Pregunta: ")
respuesta = modelo.generate_content(prompt)
print(respuesta.text)

# %%
#procesarmiento de datos
valores = [27, 30, 16]
prompt = f"Analiza esta lista de temperaturas en grados celsius y dame la respuesta en grados farenheits: {valores}"
respuesta = modelo.generate_content(prompt)
print(respuesta.text)

# %%
continuar="si"
while continuar=="si":
  prompt = input("Pregunta/salir: ")
  if prompt=="salir" or prompt=="si":
    continuar="no"
  else:
    historial.append({
        "role":"user",
        "texto": prompt,
        "timestamp": datetime.now()
    })
    respuesta = chat.send_message(prompt)

    historial.append({
        "role":"modelo",
        "texto": respuesta.text,
        "timestamp": datetime.now()
    })
    print(respuesta.text)
print(historial)

# %%
#procesarmiento de datos
valores = [27, 30, 16]
prompt = f"Analiza esta lista de temperaturas en grados celsius y dame la respuesta en grados farenheits: {valores}"
respuesta = modelo.generate_content(prompt)
print(respuesta.text)
